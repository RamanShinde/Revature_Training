# %% [markdown]
# # How to see optimize Doing Real work
# ## **Step 1:Write many files artificially**

# %%
for i in range(20):
  df=spark.createDataFrame([(i, f'name{i}', i+1000)], ['id', 'name', 'salary'])
  df.write.format("delta").mode('append').save("/Volumes/workspace/default/secondvoulmn/employees_delta_big")

# %%
# %sql
optimize delta.`/Volumes/workspace/default/secondvoulmn/employees_delta_big`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>dbfs:/Volumes/workspace/default/secondvoulmn/employees_delta_big</td><td>List(1, 40, List(1441, 1441, 1441.0, 1, 1441), List(1023, 1029, 1026.35, 40, 41054), 0, null, null, 0, 1, 40, 0, true, 0, 0, 1763621687088, 1763621690250, 8, 1, null, List(0, 0), null, 3, 3, 511, 0, null)</td></tr></tbody></table></div>
