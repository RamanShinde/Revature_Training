# %%
# %sql

create database metaDb;
use metaDb;

# %%
# %sql
select current_database();
show databases
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>databaseName</th></tr></thead><tbody><tr><td>default</td></tr><tr><td>information_schema</td></tr><tr><td>metadb</td></tr><tr><td>taxi_demo_db</td></tr></tbody></table></div>

# %%
data=[
  (1,"ravi","Electronics",1500.0),
  (2,"Meena","Grocery",500.0),
  (3,"Arjun","Clothing",800.0),
  (4,"Priya","Electronics",900.0)
]

columns=["order_id","cname","category","price"]

df=spark.createDataFrame(data,columns)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>cname</th><th>category</th><th>price</th></tr></thead><tbody><tr><td>1</td><td>ravi</td><td>Electronics</td><td>1500.0</td></tr><tr><td>2</td><td>Meena</td><td>Grocery</td><td>500.0</td></tr><tr><td>3</td><td>Arjun</td><td>Clothing</td><td>800.0</td></tr><tr><td>4</td><td>Priya</td><td>Electronics</td><td>900.0</td></tr></tbody></table></div>

# %%
df.write.mode("overwrite").saveAsTable("metadb.daily_orders_managed")

# %%
# %sql
use metadb;
show tables;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>metadb</td><td>daily_orders_managed</td><td>false</td></tr></tbody></table></div>

# %%
# %sql
describe extended daily_orders_managed;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
